# %% [markdown]
# <a href="https://colab.research.google.com/github/tarupathak30/machine_learning_algorithms/blob/main/LogisticRegression/Classifier_Metrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1a365ba5-2da4-42ad-b528-63023147a062" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a365ba5-2da4-42ad-b528-63023147a062">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Accuracy Metric

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/HeartDiseaseTrain-Test.csv')

# %%
df['target'].value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.iloc[:, 0:-1], df.iloc[:, -1], test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

categorical_columns = x_train.select_dtypes(include='object').columns.tolist()

for column in categorical_columns:
  x_train[column] = label_encoder.fit_transform(x_train[column])
  x_test[column] = label_encoder.transform(x_test[column])

y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
clf1 = LogisticRegression()
clf2 = DecisionTreeClassifier(max_depth=5, min_samples_split=10, random_state=42)

# %%
clf1.fit(x_train, y_train)
clf2.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_split=10, random_state=42)

# %%
y_pred1 = clf1.predict(x_test)
y_pred2 = clf2.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
print("Accuracy of Logistic Regression : ", accuracy_score(y_test, y_pred1))
print("Accuracy of Decision Tree : ", accuracy_score(y_test, y_pred2))
# Out:
# Accuracy of Logistic Regression :  0.7853658536585366
# Accuracy of Decision Tree :  0.8439024390243902

# %% [markdown]
# Confusion Metric

# %%
confusion_matrix(y_test, y_pred1)
# Out:
# array([[74, 28],
#        [16, 87]])

# %%
from sklearn.metrics import recall_score, precision_score, f1_score

# %%
print("For Logistic Regression Model")
print("-" * 50)

cdf = pd.DataFrame(confusion_matrix(y_test, y_pred1), columns=list(range(0, 2)))
print(cdf)

print("-"*50)
print("Precision : ", precision_score(y_test, y_pred1))
print("Recall : ", recall_score(y_test, y_pred1))
print("F1 Score :", f1_score(y_test, y_pred1))
# Out:
# For Logistic Regression Model
# --------------------------------------------------
#     0   1
# 0  74  28
# 1  16  87
# --------------------------------------------------
# Precision :  0.7565217391304347
# Recall :  0.8446601941747572
# F1 Score : 0.7981651376146789

# %%
print("For Decision Tree Model")
print("-"*50)
cdf = pd.DataFrame(confusion_matrix(y_test, y_pred2), columns=list(range(0, 2)))

print(cdf)
print("-"*50)
print("Precision : ", precision_score(y_test, y_pred2))
print("Recall : ", recall_score(y_test, y_pred2))
print("F1 Score : ", f1_score(y_test, y_pred2))
# Out:
# For Decision Tree Model
# --------------------------------------------------
#     0   1
# 0  82  20
# 1  12  91
# --------------------------------------------------
# Precision :  0.8198198198198198
# Recall :  0.883495145631068
# F1 Score :  0.8504672897196262
